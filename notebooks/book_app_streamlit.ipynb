# %%
# !pip install streamlit xgboost joblib requests pyngrok -q
print("Done")
# Out:
# Done

# %%
from google.colab import files

print("Upload these 6 files:")
print("1. app.py")
print("2. best_model.pkl")
print("3. scaler.pkl")
print("4. label_encoder.pkl")
print("5. feature_columns.pkl")
print("6. num_cols.pkl")

uploaded = files.upload()
print("Uploaded:", list(uploaded.keys()))
# Out:
# Upload these 6 files:
# 1. app.py
# 2. best_model.pkl
# 3. scaler.pkl
# 4. label_encoder.pkl
# 5. feature_columns.pkl
# 6. num_cols.pkl
#      <input type="file" id="files-19e73852-4c85-422a-ad5f-82db3a95feae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-19e73852-4c85-422a-ad5f-82db3a95feae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %%
import os

required = ["app.py", "best_model.pkl", "scaler.pkl",
            "label_encoder.pkl", "feature_columns.pkl", "num_cols.pkl"]

print("File check:")
all_good = True
for f in required:
    exists = os.path.exists(f)
    status = "✅" if exists else "❌ MISSING"
    print(f"  {status} {f}")
    if not exists:
        all_good = False

print()
if all_good:
    print("All files present — ready to launch!")
else:
    print("Upload missing files before continuing")
# Out:
# File check:
#   ✅ app.py
#   ✅ best_model.pkl
#   ✅ scaler.pkl
#   ✅ label_encoder.pkl
#   ✅ feature_columns.pkl
#   ✅ num_cols.pkl
#
# All files present — ready to launch!

# %%
import subprocess
import time
from pyngrok import conf, ngrok

# ── Paste your ngrok token here ──
NGROK_TOKEN = "3ER4xxxxxx3npzjNFBisxxxxxxxsJCXL14WqxxxxxZC"

# Kill any existing streamlit
import os
os.system("pkill -f streamlit")
time.sleep(2)

# Set ngrok token
ngrok.set_auth_token(NGROK_TOKEN)

# Start streamlit
process = subprocess.Popen(
    ["streamlit", "run", "app.py",
     "--server.port", "8501",
     "--server.headless", "true",
     "--server.enableCORS", "false"],
    stdout=subprocess.PIPE,
    stderr=subprocess.PIPE
)

time.sleep(6)

# Create public URL
public_url = ngrok.connect(8501)
print("=" * 50)
print("✅ App is LIVE!")
print(f"🌐 URL: {public_url}")
print("=" * 50)
print("Click the URL above to open the app")
print("Stop: Runtime → Interrupt execution")
# Out:
# ...
# ✅ App is LIVE!
# 🌐 URL: NgrokTunnel: "https://veteran-trend-rinsing.ngrok-free.dev" -> "http://localhost:8501"
# ...
# Click the URL above to open the app
# Stop: Runtime → Interrupt execution

# %%
import requests

# Paste fresh key here
GEMINI_API_KEY = "xxxxxxxGOUxxxxxxxxxxxxKwTcA"   # your actual key

url = f"https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent?key={GEMINI_API_KEY}"

r = requests.post(url,
    headers={"Content-Type": "application/json"},
    json={"contents": [{"parts": [{"text": "Say hello"}]}]},
    timeout=30)

print("Status:", r.status_code)
print("Response:", r.text[:300])
# Out:
# Status: 429
# Response: {
#   "error": {
#     "code": 429,
#     "message": "You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota ex

# %%
import os, subprocess, time
from pyngrok import ngrok

os.system("pkill -f streamlit")
ngrok.kill()
time.sleep(3)

process = subprocess.Popen(
    ["streamlit", "run", "app.py",
     "--server.port", "8501",
     "--server.headless", "true"],
    stdout=subprocess.PIPE,
    stderr=subprocess.PIPE
)

time.sleep(6)
ngrok.set_auth_token("3Exxxxxxxxxc_4PFL6xxxxxxxxxxxxxC")
url = ngrok.connect(8501)
print(f"✅ App restarted! URL: {url}")
# Out:
# ✅ App restarted! URL: NgrokTunnel: "https://veteran-trend-rinsing.ngrok-free.dev" -> "http://localhost:8501"
